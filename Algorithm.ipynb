# %% [markdown]
# <a href="https://colab.research.google.com/github/jessicanigre-droid/Data-Structures-and-Algorithms/blob/main/Algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
